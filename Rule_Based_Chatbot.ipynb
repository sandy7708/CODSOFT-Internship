# %% [markdown]
# <a href="https://colab.research.google.com/github/sandy7708/CODSOFT-Internship/blob/main/Rule_Based_Chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Rule-Based Chatbot

print("🤖 ChatBot: Hello! Type 'bye' to exit.")

while True:
    user = input("You: ").lower()

    if user == "hello" or user == "hi":
        print("🤖 ChatBot: Hello! How can I help you?")

    elif "how are you" in user:
        print("🤖 ChatBot: I'm doing great! Thanks for asking.")

    elif "your name" in user:
        print("🤖 ChatBot: I am a simple rule-based chatbot.")

    elif "help" in user:
        print("🤖 ChatBot: I can answer simple questions like greetings, time, date, and my name.")

    elif "time" in user:
        from datetime import datetime
        print("🤖 ChatBot: Current time is", datetime.now().strftime("%H:%M:%S"))

    elif "date" in user:
        from datetime import datetime
        print("🤖 ChatBot: Today's date is", datetime.now().strftime("%d-%m-%Y"))

    elif "thank you" in user or "thanks" in user:
        print("🤖 ChatBot: You're welcome!")

    elif user == "bye":
        print("🤖 ChatBot: Goodbye! Have a nice day.")
        break

    else:
        print("🤖 ChatBot: Sorry, I don't understand that. Please try another question.")
# Out:
# 🤖 ChatBot: Hello! Type 'bye' to exit.
# You: hi
# 🤖 ChatBot: Hello! How can I help you?
# You: how are you
# 🤖 ChatBot: I'm doing great! Thanks for asking.
# You: what is your name
# 🤖 ChatBot: I am a simple rule-based chatbot.
# You: thank you
# 🤖 ChatBot: You're welcome!
# You: bye
# 🤖 ChatBot: Goodbye! Have a nice day.
